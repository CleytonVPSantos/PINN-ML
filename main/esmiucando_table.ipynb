# %%
import pandas as pd
from decimal import Decimal, ROUND_HALF_UP

# %%
table = pd.read_csv("table.csv").round(decimals=5)
table
# Out:
#     n_hidden_layers  hidden_size  epochs  data_size     loss  training_time
# 0               3.0         80.0    50.0       80.0  0.00462      127.93830
# 1               3.0         80.0    50.0      100.0  0.00469      128.44669
# 2               3.0         80.0    50.0      120.0  0.00474      128.38770
# 3               3.0        100.0    50.0       80.0  0.00377      159.59582
# 4               3.0        100.0    50.0      100.0  0.00347      159.80528
# 5               3.0        100.0    50.0      120.0  0.00466      159.94902
# 6               3.0        120.0    50.0       80.0  0.00952      183.30284
# 7               3.0        120.0    50.0      100.0  0.00386      183.61090
# 8               3.0        120.0    50.0      120.0  0.00772      183.82800
# 9               5.0         80.0    50.0       80.0  0.01119      221.58076
# 10              5.0         80.0    50.0      100.0  0.01064      222.09892
# 11              5.0         80.0    50.0      120.0  0.01005      222.55990
# 12              5.0        100.0    50.0       80.0  0.01212      277.20944
# 13              5.0        100.0    50.0      100.0  0.01508      277.69725
# 14              5.0        100.0    50.0      120.0  0.01344      278.45335
# 15              5.0        120.0    50.0       80.0  0.00820      320.13504
# 16              5.0        120.0    50.0      100.0  0.00870      320.34141
# 17              5.0        120.0    50.0      120.0  0.00807      321.19595
# 18              6.0         80.0    50.0       80.0  0.01697      221.53968
# 19              6.0         80.0    50.0      100.0  0.00653      221.85930
# 20              6.0         80.0    50.0      120.0  0.01145      222.53261
# 21              6.0        100.0    50.0       80.0  0.01766      277.39792
# 22              6.0        100.0    50.0      100.0  0.01910      277.71371
# 23              6.0        100.0    50.0      120.0  0.00928      278.35647
# 24              6.0        120.0    50.0       80.0  0.00646      319.96288
# 25              6.0        120.0    50.0      100.0  0.01305      320.29870

# %%
table.to_csv("processed_table.csv")

# %%
# buscando melhor razão loss/training_time

table['lossPtraining_time'] = table['loss'] * table['training_time']
print(table[table.lossPtraining_time == table.lossPtraining_time.min()])

table[table.lossPtraining_time == table.lossPtraining_time.min()].to_csv("best_config.csv")
# Out:
#    n_hidden_layers  hidden_size  epochs  data_size     loss  training_time  \
# 4              3.0        100.0    50.0      100.0  0.00347      159.80528
#
#    lossPtraining_time
# 4            0.554524

# %%
# buscando efeito marginal dos dados

#esse nao sei como faz ainda
